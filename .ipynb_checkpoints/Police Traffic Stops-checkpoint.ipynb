# %% [markdown]
# # Kong-Qian-Police Traffic Stops

# %% [markdown]
# Based on a [San Diego news article](https://www.sandiegouniontribune.com/news/watchdog/story/2022-01-16/stopped-by-police-in-san-diego-a-lot-depends-on-where-you-live-drive), an analysis showed that “some areas with large minority populations saw more enforcement than mostly White areas with similar crime totals”. With this, we want to see if we can get the same results using the San Diego police dataset, provided by the Open Police Project, and perhaps dig deeper into different factors that may contribute to or even result from this. We are hoping to see whether there’s any racial discrimination against certain populations based on the location of the stop along with the driver’s race. We can even investigate whether this leads to more warnings, citations, or arrests depending on the driver’s race.

# %% [markdown]
# After taking a look at the dataset, we realized that it unfortunately does not have a location attribute, but instead a police service area number. With the help of the shapefiles provided from the same data source, we were able to get the 9 different police districts in San Diego county along with its precise location in the geometry column. Within each of the districts, there are multiple [service area numbers](https://www.sandiego.gov/sites/default/files/cros_area_map.pdf), to which we plan on merging the datasets to get the precise geometry for each police stop. This will help us potentially look into where people got stopped and if that location is in an area that has a predominantly minority population or white. Thus we will need to geoenrich the geometries or get census data for San Diego county to figure out the demographics of each district. The data itself, however, is fairly cleaned already with the only slight issue being some columns like service_areas having unknown or random values. But overall the data available is capable of helping us determine and even crossrefrence who is getting stopped the most in a certain district and if that area is largely populated by miniorites or not.

# %% [markdown]
# ### NOTES
# important links:
#
# - https://api.census.gov/data/2016/acs/acs1/variables.html
# - https://geographicdata.science/book/data/sandiego/sandiego_tracts_cleaning.html
# - https://afraenkel.github.io/fairness-algo-decision/assignments/inequity-analysis/
#
# potential downfalls:
# - acs census data from the cenpy api currently only has 2017 data while the police dataset from Stanford is from 2020.

# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import cenpy
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Collection

# %%
df = pd.read_csv('ca_san_diego_2020_04_01.csv')
#service_divisions = gpd.read_file('shapefiles/divisions_datasd.shp')
#service_divisions = gpd.read_file('/Users/brian/Downloads/ca_san_diego_shapefiles/divisions_datasd.shp')
service_divisions = gpd.read_file('ca_san_diego_shapefiles/divisions_datasd.shp')

# %%
acs = cenpy.products.ACS(2017)
vars_to_download = {
    #"B01003_001E": "total_pop",           # Total population
    #"B02001_002E": "white",     # Total white population
    #"B02001_003E": "black",
    #"B02001_004E": "native american",
    #"B02001_005E": "asian",
    #"B02001_006E": "pacific islander",
    #"B02001_007E": "other",
    "B03002_001E": "total_pop",
    "B03002_003E": "white",
    "B03002_004E": "black",
    "B03002_005E": "native american",
    "B03002_006E": "asian",
    "B03002_007E": "pacific islander",
    "B03002_008E": "other_1",
    "B03002_009E": "other_2",
    "B03002_010E": "other_3",
    "B03002_011E": "other_4",
    "B03002_012E": "hispanic",
}
vars_to_download_l = list(vars_to_download.keys())

# %%
db = acs.from_msa("San Diego, CA",
                  level="tract",
                  variables=vars_to_download_l
                 )
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pyproj/crs/crs.py:131: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /opt/anaconda3/lib/python3.7/site-packages/pyproj/crs/crs.py:131: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /opt/anaconda3/lib/python3.7/site-packages/cenpy/products.py:749: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   msa, variables, level, "Metropolitan Statistical Area", **kwargs

# %%
var_names = acs.variables\
               .reindex(vars_to_download)\
               [["label", "concept"]]\
               .reset_index()\
               .rename(columns={"index": "var_id"})
var_names["short_name"] = var_names["var_id"].map(vars_to_download)
db = db.rename(columns=vars_to_download)

# %%
db = db.to_crs(2230)
db.head()
# Out:
#          GEOID                                           geometry  total_pop  \
# 0  06073018510  POLYGON ((6222400.870 2021313.142, 6222599.301...     3057.0
# 1  06073019803  POLYGON ((6232169.917 2011395.925, 6232180.359...     4937.0
# 2  06073017502  POLYGON ((6243828.072 1962813.808, 6243881.039...     3959.0
# 3  06073017303  POLYGON ((6244663.651 1950631.608, 6244807.518...     3009.0
# 4  06073017200  POLYGON ((6247400.704 1938073.403, 6247688.230...     4338.0
#
#     white  black  native american  asian  pacific islander  other_1  other_2  \
# 0  1212.0  133.0              7.0  103.0               5.0      8.0     89.0
# 1  3495.0   88.0             43.0  421.0               0.0      0.0    251.0
# 2  2365.0   19.0              8.0  114.0              55.0      7.0    107.0
# 3  2562.0   19.0              0.0   91.0               0.0      0.0     71.0
# 4  3960.0   21.0              0.0  112.0               0.0      0.0     42.0
#
#    other_3  other_4  hispanic  \
# 0      7.0     82.0    1500.0
# 1      0.0    251.0     639.0
# 2      0.0    107.0    1284.0
# 3      0.0     71.0     266.0
# 4      0.0     42.0     203.0
#
#                                                 NAME state county   tract
# 0  Census Tract 185.10, San Diego County, California    06    073  018510
# 1  Census Tract 198.03, San Diego County, California    06    073  019803
# 2  Census Tract 175.02, San Diego County, California    06    073  017502
# 3  Census Tract 173.03, San Diego County, California    06    073  017303
# 4     Census Tract 172, San Diego County, California    06    073  017200

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df.head()
# Out:
#   raw_row_number        date      time service_area  subject_age  \
# 0              1  2014-01-01  01:25:00          110         24.0
# 1              2  2014-01-01  05:47:00          320         42.0
# 2              3  2014-01-01  07:46:00          320         29.0
# 3              4  2014-01-01  08:10:00          610         23.0
# 4              5  2014-01-01  08:35:00          930         35.0
#
#              subject_race subject_sex       type arrest_made citation_issued  \
# 0                   white        male  vehicular       False            True
# 1                   white        male  vehicular       False           False
# 2  asian/pacific islander        male  vehicular       False           False
# 3                   white        male  vehicular       False            True
# 4                hispanic        male  vehicular       False            True
#
#   warning_issued   outcome contraband_found  search_conducted search_person  \
# 0          False  citation              NaN             False         False
# 1           True   warning              NaN             False         False
# 2           True   warning              NaN             False         False
# 3          False  citation              NaN             False         False
# 4          False  citation              NaN             False         False
#
#   search_vehicle search_basis reason_for_search      reason_for_stop  \
# 0          False          NaN               NaN     Moving Violation
# 1          False          NaN               NaN     Moving Violation
# 2          False          NaN               NaN     Moving Violation
# 3          False          NaN               NaN     Moving Violation
# 4          False          NaN               NaN  Equipment Violation
#
#   raw_action_taken raw_subject_race_description
# 0         Citation                        WHITE
# 1   Verbal Warning                        WHITE
# 2   Verbal Warning                      LAOTIAN
# 3         Citation                        WHITE
# 4         Citation                     HISPANIC

# %% [markdown]
# # Exploratory Data Analysis

# %%
df['subject_race'].value_counts()
# Out:
# white                     162226
# hispanic                  117083
# black                      42705
# asian/pacific islander     32541
# other                      27238
# Name: subject_race, dtype: int64

# %%
print("Police Service Areas and the count of police stops in those areas")
df['service_area'].value_counts()
# Out:
# Police Service Areas and the count of police stops in those areas
# 310         31511
# 120         30838
# 520         29514
# 710         26824
# 240         25428
# 930         24797
# 110         24300
# 620         20951
# 230         19899
# 610         18999
# 720         17430
# 320         16529
# 430         15632
# 510         14897
# 810         13929
# 440         13710
# 830         13295
# 820         12268
# Unknown     11240
# 530           649
# 630           201
# 130            90
# County         42
# 840            28
# Bulletin       26
# Name: service_area, dtype: int64

# %%
temp = df.groupby('service_area')['subject_race'].value_counts()
pd.DataFrame(temp)
# Out:
#                                      subject_race
# service_area subject_race
# 110          white                          14505
#              hispanic                        4418
#              asian/pacific islander          2018
#              other                           1687
#              black                           1354
# 120          white                          20767
#              hispanic                        4477
#              other                           2324
#              black                           1752
#              asian/pacific islander          1419
# 130          white                             55
#              hispanic                          20
#              black                              7
#              other                              4
#              asian/pacific islander             3
# 230          white                          10967
#              asian/pacific islander          2894
#              hispanic                        2628
#              other                           2247
#              black                           1136
# 240          white                          10439
#              asian/pacific islander          5953
#              hispanic                        3785
#              other                           3493
#              black                           1730
# 310          white                          15851
#              hispanic                        6106
#              asian/pacific islander          3619
#              black                           3088
#              other                           2718
# 320          white                           8832
#              hispanic                        3226
#              black                           1983
#              other                           1390
#              asian/pacific islander          1059
# 430          hispanic                        5809
#              black                           5388
#              white                           2024
#              asian/pacific islander          1621
#              other                            765
# 440          hispanic                        7274
#              black                           3913
#              white                           1224
#              asian/pacific islander           705
#              other                            565
# 510          hispanic                        8142
#              white                           3549
#              black                           2230
#              other                            510
#              asian/pacific islander           446
# 520          white                          14508
#              hispanic                        6310
#              black                           4044
#              other                           3194
#              asian/pacific islander          1377
# 530          white                            388
#              hispanic                         136
#              asian/pacific islander            53
#              black                             37
#              other                             33
# 610          white                          12456
#              hispanic                        3430
#              black                           1408
#              other                            832
#              asian/pacific islander           800
# 620          white                          11423
#              hispanic                        4713
#              black                           1987
#              asian/pacific islander          1593
#              other                           1161
# 630          white                            104
#              hispanic                          37
#              asian/pacific islander            30
#              black                             16
#              other                             13
# 710          hispanic                       21896
#              white                           3087
#              black                            776
#              asian/pacific islander           608
#              other                            437
# 720          hispanic                       12581
#              white                           2649
#              black                           1089
#              asian/pacific islander           750
#              other                            348
# 810          white                           6180
#              hispanic                        3928
#              black                           2142
#              other                            905
#              asian/pacific islander           753
# 820          hispanic                        3724
#              black                           3419
#              white                           2804
#              asian/pacific islander          1457
#              other                            835
# 830          hispanic                        6106
#              black                           2871
#              white                           2477
#              asian/pacific islander          1212
#              other                            609
# 840          hispanic                          13
#              white                              9
#              other                              3
#              asian/pacific islander             2
#              black                              1
# 930          white                          13491
#              hispanic                        4136
#              asian/pacific islander          3396
#              other                           2481
#              black                           1205
# Unknown      white                           4437
#              hispanic                        4188
#              black                           1129
#              asian/pacific islander           773
#              other                            684

# %%
df.groupby('outcome')['subject_race'].value_counts()
# Out:
# outcome   subject_race
# arrest    white                      1771
#           hispanic                   1714
#           black                       857
#           asian/pacific islander      309
#           other                       160
# citation  white                     96062
#           hispanic                  67298
#           black                     20523
#           asian/pacific islander    17805
#           other                     17289
# warning   white                     50107
#           hispanic                  33461
#           black                     16606
#           asian/pacific islander    11887
#           other                      7049
# Name: subject_race, dtype: int64

# %% [markdown]
# # Investigation

# %%
print("Police districts in San Diego")
service_divisions
# Out:
# Police districts in San Diego
#    objectid  div_num      div_name  \
# 0         1        1      NORTHERN
# 1         2        2  NORTHEASTERN
# 2         3        3       EASTERN
# 3         4        4  SOUTHEASTERN
# 4         5        5       CENTRAL
# 5         6        6       WESTERN
# 6         7        7      SOUTHERN
# 7         8        8      MID-CITY
# 8         9        9  NORTHWESTERN
#
#                                             geometry
# 0  POLYGON ((6257399.474 1913720.405, 6258021.781...
# 1  POLYGON ((6329136.046 1985638.386, 6329132.056...
# 2  POLYGON ((6323355.804 1898933.226, 6324130.958...
# 3  POLYGON ((6314753.250 1851441.908, 6314774.253...
# 4  POLYGON ((6287304.000 1850636.000, 6287303.000...
# 5  POLYGON ((6280788.358 1873275.706, 6280793.053...
# 6  POLYGON ((6294084.233 1801858.103, 6294115.999...
# 7  POLYGON ((6300696.000 1863112.000, 6300797.593...
# 8  POLYGON ((6290347.459 1952824.477, 6290674.051...

# %%
districts = {'NORTHERN': ['110','120','130'], 'NORTHEASTERN': ['230','240'], "EASTERN": ['310','320'], 'SOUTHEASTERN':['430','440'], 'CENTRAL':['510','520','530'], 'WESTERN':['610','620','630'], 'SOUTHERN':['710','720'], 'MID-CITY':['810','820','830', '840'], 'NORTHWESTERN':['930']}
districts
# Out:
# {'NORTHERN': ['110', '120', '130'],
#  'NORTHEASTERN': ['230', '240'],
#  'EASTERN': ['310', '320'],
#  'SOUTHEASTERN': ['430', '440'],
#  'CENTRAL': ['510', '520', '530'],
#  'WESTERN': ['610', '620', '630'],
#  'SOUTHERN': ['710', '720'],
#  'MID-CITY': ['810', '820', '830', '840'],
#  'NORTHWESTERN': ['930']}

# %%
df['service_area'].unique()
# Out:
# array(['110', '320', '610', '930', '820', '710', '120', '230', '240',
#        '720', '430', '310', '510', 'Unknown', '810', '440', '830', '520',
#        '620', '630', '130', '530', '840', 'County', 'Bulletin'],
#       dtype=object)

# %%
service_divisions['service_area'] = service_divisions['div_name'].map(districts)
service_divisions
# Out:
#    objectid  div_num      div_name  \
# 0         1        1      NORTHERN
# 1         2        2  NORTHEASTERN
# 2         3        3       EASTERN
# 3         4        4  SOUTHEASTERN
# 4         5        5       CENTRAL
# 5         6        6       WESTERN
# 6         7        7      SOUTHERN
# 7         8        8      MID-CITY
# 8         9        9  NORTHWESTERN
#
#                                             geometry          service_area
# 0  POLYGON ((6257399.474 1913720.405, 6258021.781...       [110, 120, 130]
# 1  POLYGON ((6329136.046 1985638.386, 6329132.056...            [230, 240]
# 2  POLYGON ((6323355.804 1898933.226, 6324130.958...            [310, 320]
# 3  POLYGON ((6314753.250 1851441.908, 6314774.253...            [430, 440]
# 4  POLYGON ((6287304.000 1850636.000, 6287303.000...       [510, 520, 530]
# 5  POLYGON ((6280788.358 1873275.706, 6280793.053...       [610, 620, 630]
# 6  POLYGON ((6294084.233 1801858.103, 6294115.999...            [710, 720]
# 7  POLYGON ((6300696.000 1863112.000, 6300797.593...  [810, 820, 830, 840]
# 8  POLYGON ((6290347.459 1952824.477, 6290674.051...                 [930]

# %%
service_divisions = service_divisions.explode('service_area')
service_divisions = service_divisions[['service_area','geometry']]
service_divisions
# Out:
#   service_area                                           geometry
# 0          110  POLYGON ((6257399.474 1913720.405, 6258021.781...
# 0          120  POLYGON ((6257399.474 1913720.405, 6258021.781...
# 0          130  POLYGON ((6257399.474 1913720.405, 6258021.781...
# 1          230  POLYGON ((6329136.046 1985638.386, 6329132.056...
# 1          240  POLYGON ((6329136.046 1985638.386, 6329132.056...
# 2          310  POLYGON ((6323355.804 1898933.226, 6324130.958...
# 2          320  POLYGON ((6323355.804 1898933.226, 6324130.958...
# 3          430  POLYGON ((6314753.250 1851441.908, 6314774.253...
# 3          440  POLYGON ((6314753.250 1851441.908, 6314774.253...
# 4          510  POLYGON ((6287304.000 1850636.000, 6287303.000...
# 4          520  POLYGON ((6287304.000 1850636.000, 6287303.000...
# 4          530  POLYGON ((6287304.000 1850636.000, 6287303.000...
# 5          610  POLYGON ((6280788.358 1873275.706, 6280793.053...
# 5          620  POLYGON ((6280788.358 1873275.706, 6280793.053...
# 5          630  POLYGON ((6280788.358 1873275.706, 6280793.053...
# 6          710  POLYGON ((6294084.233 1801858.103, 6294115.999...
# 6          720  POLYGON ((6294084.233 1801858.103, 6294115.999...
# 7          810  POLYGON ((6300696.000 1863112.000, 6300797.593...
# 7          820  POLYGON ((6300696.000 1863112.000, 6300797.593...
# 7          830  POLYGON ((6300696.000 1863112.000, 6300797.593...
# 7          840  POLYGON ((6300696.000 1863112.000, 6300797.593...
# 8          930  POLYGON ((6290347.459 1952824.477, 6290674.051...

# %%
test = gpd.sjoin(left_df=service_divisions, right_df=db, how='left')

# %%
test.head()
# Out:
#   service_area                                           geometry  \
# 0          110  POLYGON ((6257399.474 1913720.405, 6258021.781...
# 0          110  POLYGON ((6257399.474 1913720.405, 6258021.781...
# 0          110  POLYGON ((6257399.474 1913720.405, 6258021.781...
# 0          110  POLYGON ((6257399.474 1913720.405, 6258021.781...
# 0          110  POLYGON ((6257399.474 1913720.405, 6258021.781...
#
#    index_right        GEOID  total_pop   white  black  native american  \
# 0          449  06073009400     4645.0  2641.0  395.0            102.0
# 0          183  06073008511     4336.0  1712.0  176.0              0.0
# 0          170  06073008506     4753.0  2555.0   64.0              0.0
# 0           21  06073008505     6571.0  3036.0   81.0             15.0
# 0          582  06073008345     4170.0  2716.0  125.0             16.0
#
#     asian  pacific islander  other_1  other_2  other_3  other_4  hispanic  \
# 0   121.0               9.0     37.0    154.0      0.0    154.0    1186.0
# 0   906.0             127.0      0.0    131.0     43.0     88.0    1284.0
# 0   588.0               0.0      0.0     78.0      0.0     78.0    1468.0
# 0  1459.0             109.0     21.0    154.0     26.0    128.0    1696.0
# 0   633.0               0.0      0.0    100.0      0.0    100.0     580.0
#
#                                                NAME state county   tract
# 0     Census Tract 94, San Diego County, California    06    073  009400
# 0  Census Tract 85.11, San Diego County, California    06    073  008511
# 0  Census Tract 85.06, San Diego County, California    06    073  008506
# 0  Census Tract 85.05, San Diego County, California    06    073  008505
# 0  Census Tract 83.45, San Diego County, California    06    073  008345

# %%
divisions = test.groupby('service_area').sum()
divisions['other'] = divisions['total_pop'] - divisions['white'] - divisions['black'] - divisions['asian'] - divisions['pacific islander'] - divisions['hispanic']
divisions['asian/pacific islander'] = divisions['asian'] + divisions['pacific islander'] 
#divisions['other'] = divisions['native american'] + divisions['other_1'] + divisions['other_2'] + divisions['other_3'] + divisions['other_4']
divisions = divisions.reset_index()[['service_area','total_pop','white','black','asian/pacific islander','hispanic','other']]

# %%
final_divisions = divisions.merge(service_divisions, on='service_area')
final_divisions
# Out:
#    service_area  total_pop     white    black  asian/pacific islander  \
# 0           110   274271.0  167769.0   6907.0                 40788.0
# 1           120   274271.0  167769.0   6907.0                 40788.0
# 2           130   274271.0  167769.0   6907.0                 40788.0
# 3           230   379929.0  194353.0   8910.0                106724.0
# 4           240   379929.0  194353.0   8910.0                106724.0
# 5           310   267640.0  157171.0  14162.0                 29680.0
# 6           320   267640.0  157171.0  14162.0                 29680.0
# 7           430   299131.0   43770.0  39683.0                 51147.0
# 8           440   299131.0   43770.0  39683.0                 51147.0
# 9           510   162981.0   67667.0  11426.0                  9464.0
# 10          520   162981.0   67667.0  11426.0                  9464.0
# 11          530   162981.0   67667.0  11426.0                  9464.0
# 12          610   205228.0  129765.0   8069.0                 17832.0
# 13          620   205228.0  129765.0   8069.0                 17832.0
# 14          630   205228.0  129765.0   8069.0                 17832.0
# 15          710   177437.0   23370.0   8067.0                 20728.0
# 16          720   177437.0   23370.0   8067.0                 20728.0
# 17          810   263881.0   98943.0  26792.0                 30643.0
# 18          820   263881.0   98943.0  26792.0                 30643.0
# 19          830   263881.0   98943.0  26792.0                 30643.0
# 20          840   263881.0   98943.0  26792.0                 30643.0
# 21          930   191122.0  105880.0   3566.0                 53185.0
#
#     hispanic    other                                           geometry
# 0    47961.0  10846.0  POLYGON ((6257399.474 1913720.405, 6258021.781...
# 1    47961.0  10846.0  POLYGON ((6257399.474 1913720.405, 6258021.781...
# 2    47961.0  10846.0  POLYGON ((6257399.474 1913720.405, 6258021.781...
# 3    49681.0  20261.0  POLYGON ((6329136.046 1985638.386, 6329132.056...
# 4    49681.0  20261.0  POLYGON ((6329136.046 1985638.386, 6329132.056...
# 5    54041.0  12586.0  POLYGON ((6323355.804 1898933.226, 6324130.958...
# 6    54041.0  12586.0  POLYGON ((6323355.804 1898933.226, 6324130.958...
# 7   155721.0   8810.0  POLYGON ((6314753.250 1851441.908, 6314774.253...
# 8   155721.0   8810.0  POLYGON ((6314753.250 1851441.908, 6314774.253...
# 9    69987.0   4437.0  POLYGON ((6287304.000 1850636.000, 6287303.000...
# 10   69987.0   4437.0  POLYGON ((6287304.000 1850636.000, 6287303.000...
# 11   69987.0   4437.0  POLYGON ((6287304.000 1850636.000, 6287303.000...
# 12   41948.0   7614.0  POLYGON ((6280788.358 1873275.706, 6280793.053...
# 13   41948.0   7614.0  POLYGON ((6280788.358 1873275.706, 6280793.053...
# 14   41948.0   7614.0  POLYGON ((6280788.358 1873275.706, 6280793.053...
# 15  120828.0   4444.0  POLYGON ((6294084.233 1801858.103, 6294115.999...
# 16  120828.0   4444.0  POLYGON ((6294084.233 1801858.103, 6294115.999...
# 17   98833.0   8670.0  POLYGON ((6300696.000 1863112.000, 6300797.593...
# 18   98833.0   8670.0  POLYGON ((6300696.000 1863112.000, 6300797.593...
# 19   98833.0   8670.0  POLYGON ((6300696.000 1863112.000, 6300797.593...
# 20   98833.0   8670.0  POLYGON ((6300696.000 1863112.000, 6300797.593...
# 21   18776.0   9715.0  POLYGON ((6290347.459 1952824.477, 6290674.051...

# %%
df2 = df.merge(final_divisions, how='left')
df2.head()
# Out:
#   raw_row_number        date      time service_area  subject_age  \
# 0              1  2014-01-01  01:25:00          110         24.0
# 1              2  2014-01-01  05:47:00          320         42.0
# 2              3  2014-01-01  07:46:00          320         29.0
# 3              4  2014-01-01  08:10:00          610         23.0
# 4              5  2014-01-01  08:35:00          930         35.0
#
#              subject_race subject_sex       type arrest_made citation_issued  \
# 0                   white        male  vehicular       False            True
# 1                   white        male  vehicular       False           False
# 2  asian/pacific islander        male  vehicular       False           False
# 3                   white        male  vehicular       False            True
# 4                hispanic        male  vehicular       False            True
#
#   warning_issued   outcome contraband_found  search_conducted search_person  \
# 0          False  citation              NaN             False         False
# 1           True   warning              NaN             False         False
# 2           True   warning              NaN             False         False
# 3          False  citation              NaN             False         False
# 4          False  citation              NaN             False         False
#
#   search_vehicle search_basis reason_for_search      reason_for_stop  \
# 0          False          NaN               NaN     Moving Violation
# 1          False          NaN               NaN     Moving Violation
# 2          False          NaN               NaN     Moving Violation
# 3          False          NaN               NaN     Moving Violation
# 4          False          NaN               NaN  Equipment Violation
#
#   raw_action_taken raw_subject_race_description  total_pop     white    black  \
# 0         Citation                        WHITE   274271.0  167769.0   6907.0
# 1   Verbal Warning                        WHITE   267640.0  157171.0  14162.0
# 2   Verbal Warning                      LAOTIAN   267640.0  157171.0  14162.0
# 3         Citation                        WHITE   205228.0  129765.0   8069.0
# 4         Citation                     HISPANIC   191122.0  105880.0   3566.0
#
#    asian/pacific islander  hispanic    other  \
# 0                 40788.0   47961.0  10846.0
# 1                 29680.0   54041.0  12586.0
# 2                 29680.0   54041.0  12586.0
# 3                 17832.0   41948.0   7614.0
# 4                 53185.0   18776.0   9715.0
#
#                                             geometry
# 0  POLYGON ((6257399.474 1913720.405, 6258021.781...
# 1  POLYGON ((6323355.804 1898933.226, 6324130.958...
# 2  POLYGON ((6323355.804 1898933.226, 6324130.958...
# 3  POLYGON ((6280788.358 1873275.706, 6280793.053...
# 4  POLYGON ((6290347.459 1952824.477, 6290674.051...

# %%
temp = df.groupby('service_area')['subject_race'].value_counts(normalize=True)
pd.DataFrame(temp)
# Out:
#                                      subject_race
# service_area subject_race
# 110          white                       0.604829
#              hispanic                    0.184221
#              asian/pacific islander      0.084146
#              other                       0.070344
#              black                       0.056459
# 120          white                       0.675591
#              hispanic                    0.145646
#              other                       0.075604
#              black                       0.056996
#              asian/pacific islander      0.046163
# 130          white                       0.617978
#              hispanic                    0.224719
#              black                       0.078652
#              other                       0.044944
#              asian/pacific islander      0.033708
# 230          white                       0.551882
#              asian/pacific islander      0.145632
#              hispanic                    0.132246
#              other                       0.113074
#              black                       0.057166
# 240          white                       0.410984
#              asian/pacific islander      0.234370
#              hispanic                    0.149016
#              other                       0.137520
#              black                       0.068110
# 310          white                       0.505098
#              hispanic                    0.194570
#              asian/pacific islander      0.115321
#              black                       0.098400
#              other                       0.086610
# 320          white                       0.535597
#              hispanic                    0.195634
#              black                       0.120255
#              other                       0.084294
#              asian/pacific islander      0.064221
# 430          hispanic                    0.372205
#              black                       0.345230
#              white                       0.129685
#              asian/pacific islander      0.103864
#              other                       0.049016
# 440          hispanic                    0.531686
#              black                       0.286017
#              white                       0.089467
#              asian/pacific islander      0.051531
#              other                       0.041298
# 510          hispanic                    0.547288
#              white                       0.238556
#              black                       0.149896
#              other                       0.034281
#              asian/pacific islander      0.029979
# 520          white                       0.492916
#              hispanic                    0.214385
#              black                       0.137397
#              other                       0.108518
#              asian/pacific islander      0.046784
# 530          white                       0.599691
#              hispanic                    0.210201
#              asian/pacific islander      0.081917
#              black                       0.057187
#              other                       0.051005
# 610          white                       0.658142
#              hispanic                    0.181232
#              black                       0.074395
#              other                       0.043961
#              asian/pacific islander      0.042270
# 620          white                       0.547157
#              hispanic                    0.225751
#              black                       0.095177
#              asian/pacific islander      0.076304
#              other                       0.055611
# 630          white                       0.520000
#              hispanic                    0.185000
#              asian/pacific islander      0.150000
#              black                       0.080000
#              other                       0.065000
# 710          hispanic                    0.816893
#              white                       0.115169
#              black                       0.028951
#              asian/pacific islander      0.022683
#              other                       0.016304
# 720          hispanic                    0.722340
#              white                       0.152093
#              black                       0.062525
#              asian/pacific islander      0.043061
#              other                       0.019980
# 810          white                       0.444349
#              hispanic                    0.282427
#              black                       0.154012
#              other                       0.065070
#              asian/pacific islander      0.054142
# 820          hispanic                    0.304273
#              black                       0.279353
#              white                       0.229104
#              asian/pacific islander      0.119046
#              other                       0.068225
# 830          hispanic                    0.459962
#              black                       0.216271
#              white                       0.186591
#              asian/pacific islander      0.091299
#              other                       0.045876
# 840          hispanic                    0.464286
#              white                       0.321429
#              other                       0.107143
#              asian/pacific islander      0.071429
#              black                       0.035714
# 930          white                       0.545995
#              hispanic                    0.167388
#              asian/pacific islander      0.137440
#              other                       0.100409
#              black                       0.048768
# Unknown      white                       0.395772
#              hispanic                    0.373562
#              black                       0.100705
#              asian/pacific islander      0.068950
#              other                       0.061012

# %%
#final_divisions.groupby('service_area')

# %%
df.head(10)
# Out:
#   raw_row_number        date      time service_area  subject_age  \
# 0              1  2014-01-01  01:25:00          110         24.0
# 1              2  2014-01-01  05:47:00          320         42.0
# 2              3  2014-01-01  07:46:00          320         29.0
# 3              4  2014-01-01  08:10:00          610         23.0
# 4              5  2014-01-01  08:35:00          930         35.0
# 5              6  2014-01-01  08:39:00          820         30.0
# 6              7  2014-01-01  09:13:00          710         19.0
# 7              8  2014-01-01  09:50:00          120         32.0
# 8              9  2014-01-01  10:00:00          120         36.0
# 9             10  2014-01-01  10:40:00          120         27.0
#
#              subject_race subject_sex       type arrest_made citation_issued  \
# 0                   white        male  vehicular       False            True
# 1                   white        male  vehicular       False           False
# 2  asian/pacific islander        male  vehicular       False           False
# 3                   white        male  vehicular       False            True
# 4                hispanic        male  vehicular       False            True
# 5                hispanic        male  vehicular       False           False
# 6                hispanic      female  vehicular       False            True
# 7                   white        male  vehicular       False           False
# 8                   white        male  vehicular       False            True
# 9                hispanic        male  vehicular       False            True
#
#   warning_issued   outcome contraband_found  search_conducted search_person  \
# 0          False  citation              NaN             False         False
# 1           True   warning              NaN             False         False
# 2           True   warning              NaN             False         False
# 3          False  citation              NaN             False         False
# 4          False  citation              NaN             False         False
# 5           True   warning              NaN             False         False
# 6          False  citation              NaN             False         False
# 7           True   warning              NaN             False         False
# 8          False  citation              NaN             False         False
# 9          False  citation              NaN             False         False
#
#   search_vehicle search_basis reason_for_search      reason_for_stop  \
# 0          False          NaN               NaN     Moving Violation
# 1          False          NaN               NaN     Moving Violation
# 2          False          NaN               NaN     Moving Violation
# 3          False          NaN               NaN     Moving Violation
# 4          False          NaN               NaN  Equipment Violation
# 5          False          NaN               NaN  Equipment Violation
# 6          False          NaN               NaN     Moving Violation
# 7          False          NaN               NaN     Moving Violation
# 8          False          NaN               NaN     Moving Violation
# 9          False          NaN               NaN     Moving Violation
#
#   raw_action_taken raw_subject_race_description
# 0         Citation                        WHITE
# 1   Verbal Warning                        WHITE
# 2   Verbal Warning                      LAOTIAN
# 3         Citation                        WHITE
# 4         Citation                     HISPANIC
# 5   Verbal Warning                     HISPANIC
# 6         Citation                     HISPANIC
# 7  Written Warning                        WHITE
# 8         Citation                        WHITE
# 9         Citation                     HISPANIC

# %% [markdown]
# # Demographic Parity

# %% [markdown]
# 1. In the Demographic Parity view of fairness, the demographics of people who are ultimately searched after being stopped should be proportional the demographics of the people who were stopped.  if 80% of people stopped were Hispanic, then 80% of the people who were searched should also be 80%.

# %%
len(df)/2
# Out:
# 191513.5

# %%
#train = df.iloc[:191513,:]
test = df#.iloc[191513:,:]

# %%
test.head()
# Out:
#   raw_row_number        date      time service_area  subject_age  \
# 0              1  2014-01-01  01:25:00          110         24.0
# 1              2  2014-01-01  05:47:00          320         42.0
# 2              3  2014-01-01  07:46:00          320         29.0
# 3              4  2014-01-01  08:10:00          610         23.0
# 4              5  2014-01-01  08:35:00          930         35.0
#
#              subject_race subject_sex       type arrest_made citation_issued  \
# 0                   white        male  vehicular       False            True
# 1                   white        male  vehicular       False           False
# 2  asian/pacific islander        male  vehicular       False           False
# 3                   white        male  vehicular       False            True
# 4                hispanic        male  vehicular       False            True
#
#   warning_issued   outcome contraband_found  search_conducted search_person  \
# 0          False  citation              NaN             False         False
# 1           True   warning              NaN             False         False
# 2           True   warning              NaN             False         False
# 3          False  citation              NaN             False         False
# 4          False  citation              NaN             False         False
#
#   search_vehicle search_basis reason_for_search      reason_for_stop  \
# 0          False          NaN               NaN     Moving Violation
# 1          False          NaN               NaN     Moving Violation
# 2          False          NaN               NaN     Moving Violation
# 3          False          NaN               NaN     Moving Violation
# 4          False          NaN               NaN  Equipment Violation
#
#   raw_action_taken raw_subject_race_description
# 0         Citation                        WHITE
# 1   Verbal Warning                        WHITE
# 2   Verbal Warning                      LAOTIAN
# 3         Citation                        WHITE
# 4         Citation                     HISPANIC

# %%
def aspercent(column,decimals=2):
    assert decimals >= 0
    return (round(column*100,decimals).astype(str) + "%")

# %%
demographic_groups = test['subject_race'].value_counts().to_dict()
demographic_groups
# Out:
# {'white': 162226,
#  'hispanic': 117083,
#  'black': 42705,
#  'asian/pacific islander': 32541,
#  'other': 27238}

# %%
percentage_of_groups = aspercent(test['subject_race'].value_counts(normalize=True), decimals = 2).to_dict()
percentage_of_groups
# Out:
# {'white': '42.49%',
#  'hispanic': '30.67%',
#  'black': '11.19%',
#  'asian/pacific islander': '8.52%',
#  'other': '7.13%'}

# %%
searched_groups = test[test['search_conducted'] == True]['subject_race'].value_counts().to_dict()
searched_groups
# Out:
# {'hispanic': 6501,
#  'white': 4510,
#  'black': 3873,
#  'asian/pacific islander': 910,
#  'other': 451}

# %%
percentage_searched = aspercent(test[test['search_conducted'] == True]['subject_race'].value_counts(normalize=True),decimals=2).to_dict()
percentage_searched
# Out:
# {'hispanic': '40.02%',
#  'white': '27.76%',
#  'black': '23.84%',
#  'asian/pacific islander': '5.6%',
#  'other': '2.78%'}

# %%
searched = pd.DataFrame([demographic_groups, percentage_of_groups, searched_groups, percentage_searched],index=['Total # of Stops', 'Percent of Stops', '# of Searched', 'Percent of Searched']).T
index = searched.index
index.name = "Race"
searched.style.set_caption('Demographic Parity Fairness: Searched').set_table_styles([{
    'selector': 'caption',
    'props': [
        ('color', 'Black'),
        ('font-size', '15px'),
        ('font-style', 'italic'),
        ('font-weight', 'bold'),
        ('text-align', 'center')
    ]
}])
# Out:
# <style type="text/css">
# #T_3cfed_ caption {
#   color: Black;
#   font-size: 15px;
#   font-style: italic;
#   font-weight: bold;
#   text-align: center;
# }
# </style>
# <table id="T_3cfed_">
#   <caption>Demographic Parity Fairness: Searched</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Total # of Stops</th>
#       <th class="col_heading level0 col1" >Percent of Stops</th>
#       <th class="col_heading level0 col2" ># of Searched</th>
#       <th class="col_heading level0 col3" >Percent of Searched</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Race</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3cfed_level0_row0" class="row_heading level0 row0" >white</th>
#       <td id="T_3cfed_row0_col0" class="data row0 col0" >162226</td>
#       <td id="T_3cfed_row0_col1" class="data row0 col1" >42.49%</td>
#       <td id="T_3cfed_row0_col2" class="data row0 col2" >4510</td>
#       <td id="T_3cfed_row0_col3" class="data row0 col3" >27.76%</td>
#     </tr>
#     <tr>
#       <th id="T_3cfed_level0_row1" class="row_heading level0 row1" >hispanic</th>
#       <td id="T_3cfed_row1_col0" class="data row1 col0" >117083</td>
#       <td id="T_3cfed_row1_col1" class="data row1 col1" >30.67%</td>
#       <td id="T_3cfed_row1_col2" class="data row1 col2" >6501</td>
#       <td id="T_3cfed_row1_col3" class="data row1 col3" >40.02%</td>
#     </tr>
#     <tr>
#       <th id="T_3cfed_level0_row2" class="row_heading level0 row2" >black</th>
#       <td id="T_3cfed_row2_col0" class="data row2 col0" >42705</td>
#       <td id="T_3cfed_row2_col1" class="data row2 col1" >11.19%</td>
#       <td id="T_3cfed_row2_col2" class="data row2 col2" >3873</td>
#       <td id="T_3cfed_row2_col3" class="data row2 col3" >23.84%</td>
#     </tr>
#     <tr>
#       <th id="T_3cfed_level0_row3" class="row_heading level0 row3" >asian/pacific islander</th>
#       <td id="T_3cfed_row3_col0" class="data row3 col0" >32541</td>
#       <td id="T_3cfed_row3_col1" class="data row3 col1" >8.52%</td>
#       <td id="T_3cfed_row3_col2" class="data row3 col2" >910</td>
#       <td id="T_3cfed_row3_col3" class="data row3 col3" >5.6%</td>
#     </tr>
#     <tr>
#       <th id="T_3cfed_level0_row4" class="row_heading level0 row4" >other</th>
#       <td id="T_3cfed_row4_col0" class="data row4 col0" >27238</td>
#       <td id="T_3cfed_row4_col1" class="data row4 col1" >7.13%</td>
#       <td id="T_3cfed_row4_col2" class="data row4 col2" >451</td>
#       <td id="T_3cfed_row4_col3" class="data row4 col3" >2.78%</td>
#     </tr>
#   </tbody>
# </table>

# %%
ax = searched.plot(y="Total # of Stops", use_index=True , kind="bar", color='lavender')
searched.plot(y="# of Searched", kind="bar", ax=ax, color="plum")
plt.xlabel("Race")
plt.ylabel('Number of people')
plt.title("Distribution of Stops and Searches per Race", fontdict={'fontsize': 10, 'fontweight':'bold'})
# Out:
# Text(0.5, 1.0, 'Distribution of Stops and Searches per Race')

# %%
searched.plot(y= ['Percent of Stops',"Percent of Searched"], use_index=True, kind='bar', color =['paleturquoise','teal'])
plt.xlabel("Race")
plt.ylabel('Percentages')
plt.title("Comparison between Percentage of Stops and Searches per Race", fontdict={'fontsize': 9, 'fontweight':'bold'})
# Out:
# Text(0.5, 1.0, 'Comparison between Percentage of Stops and Searches per Race')

# %%
searched_person_groups = test[test['search_person'] == True]['subject_race'].value_counts().to_dict()
searched_person_groups
# Out:
# {'hispanic': 2683,
#  'white': 2097,
#  'black': 2008,
#  'asian/pacific islander': 464,
#  'other': 158}

# %%
percentage_searched_person = aspercent(test[test['search_person'] == True]['subject_race'].value_counts(normalize=True),decimals=2).to_dict()
percentage_searched_person
# Out:
# {'hispanic': '36.21%',
#  'white': '28.3%',
#  'black': '27.1%',
#  'asian/pacific islander': '6.26%',
#  'other': '2.13%'}

# %%
searched_person = pd.DataFrame([demographic_groups, percentage_of_groups, searched_person_groups, percentage_searched_person],index=['Total # of Stops', 'Percent of Stops', '# of Searched (Person)', 'Percent of Searched (Person)']).T
index = searched_person.index
index.name = "Race"
searched_person.style.set_caption('Demographic Parity Fairness: Searched (Person)').set_table_styles([{
    'selector': 'caption',
    'props': [
        ('color', 'Black'),
        ('font-size', '15px'),
        ('font-style', 'italic'),
        ('font-weight', 'bold'),
        ('text-align', 'center')
    ]
}])
# Out:
# <style type="text/css">
# #T_85436_ caption {
#   color: Black;
#   font-size: 15px;
#   font-style: italic;
#   font-weight: bold;
#   text-align: center;
# }
# </style>
# <table id="T_85436_">
#   <caption>Demographic Parity Fairness: Searched (Person)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Total # of Stops</th>
#       <th class="col_heading level0 col1" >Percent of Stops</th>
#       <th class="col_heading level0 col2" ># of Searched (Person)</th>
#       <th class="col_heading level0 col3" >Percent of Searched (Person)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Race</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_85436_level0_row0" class="row_heading level0 row0" >white</th>
#       <td id="T_85436_row0_col0" class="data row0 col0" >162226</td>
#       <td id="T_85436_row0_col1" class="data row0 col1" >42.49%</td>
#       <td id="T_85436_row0_col2" class="data row0 col2" >2097</td>
#       <td id="T_85436_row0_col3" class="data row0 col3" >28.3%</td>
#     </tr>
#     <tr>
#       <th id="T_85436_level0_row1" class="row_heading level0 row1" >hispanic</th>
#       <td id="T_85436_row1_col0" class="data row1 col0" >117083</td>
#       <td id="T_85436_row1_col1" class="data row1 col1" >30.67%</td>
#       <td id="T_85436_row1_col2" class="data row1 col2" >2683</td>
#       <td id="T_85436_row1_col3" class="data row1 col3" >36.21%</td>
#     </tr>
#     <tr>
#       <th id="T_85436_level0_row2" class="row_heading level0 row2" >black</th>
#       <td id="T_85436_row2_col0" class="data row2 col0" >42705</td>
#       <td id="T_85436_row2_col1" class="data row2 col1" >11.19%</td>
#       <td id="T_85436_row2_col2" class="data row2 col2" >2008</td>
#       <td id="T_85436_row2_col3" class="data row2 col3" >27.1%</td>
#     </tr>
#     <tr>
#       <th id="T_85436_level0_row3" class="row_heading level0 row3" >asian/pacific islander</th>
#       <td id="T_85436_row3_col0" class="data row3 col0" >32541</td>
#       <td id="T_85436_row3_col1" class="data row3 col1" >8.52%</td>
#       <td id="T_85436_row3_col2" class="data row3 col2" >464</td>
#       <td id="T_85436_row3_col3" class="data row3 col3" >6.26%</td>
#     </tr>
#     <tr>
#       <th id="T_85436_level0_row4" class="row_heading level0 row4" >other</th>
#       <td id="T_85436_row4_col0" class="data row4 col0" >27238</td>
#       <td id="T_85436_row4_col1" class="data row4 col1" >7.13%</td>
#       <td id="T_85436_row4_col2" class="data row4 col2" >158</td>
#       <td id="T_85436_row4_col3" class="data row4 col3" >2.13%</td>
#     </tr>
#   </tbody>
# </table>

# %%
ax = searched_person.plot(y="Total # of Stops", use_index=True , kind="bar", color='lavender')
searched_person.plot(y="# of Searched (Person)", kind="bar", ax=ax, color="plum")
plt.xlabel("Race")
plt.ylabel('Number of people')
plt.title("Distribution of Stops and Searches (Person) per Race", fontdict={'fontsize': 10, 'fontweight':'bold'})
# Out:
# Text(0.5, 1.0, 'Distribution of Stops and Searches (Person) per Race')

# %%
searched_person.plot(y= ['Percent of Stops',"Percent of Searched (Person)"], use_index=True, kind='bar', color =['paleturquoise','teal'])
plt.xlabel("Race")
plt.ylabel('Percentages')
plt.title("Comparison between Percentage of Stops and Searches (Person) per Race", fontdict={'fontsize': 9, 'fontweight':'bold'})
# Out:
# Text(0.5, 1.0, 'Comparison between Percentage of Stops and Searches (Person) per Race')

# %%
searched_vehicle_groups = test[test['search_vehicle'] == True]['subject_race'].value_counts().to_dict()
searched_vehicle_groups
# Out:
# {'hispanic': 4326,
#  'white': 2509,
#  'black': 2444,
#  'asian/pacific islander': 534,
#  'other': 279}

# %%
percentage_searched_vehicle = aspercent(test[test['search_vehicle'] == True]['subject_race'].value_counts(normalize=True),decimals=2).to_dict()
percentage_searched_vehicle
# Out:
# {'hispanic': '42.87%',
#  'white': '24.86%',
#  'black': '24.22%',
#  'asian/pacific islander': '5.29%',
#  'other': '2.76%'}

# %%
searched_vehicle =pd.DataFrame([demographic_groups, percentage_of_groups, searched_vehicle_groups, percentage_searched_vehicle],index=['Total # of Stops', 'Percent of Stops', '# of Searched (Vehicles)', 'Percent of Searched (Vehicles)']).T
index = searched_vehicle.index
index.name = "Race"
searched_vehicle.style.set_caption('Demographic Parity Fairness: Searched (Vehicles)').set_table_styles([{
    'selector': 'caption',
    'props': [
        ('color', 'Black'),
        ('font-size', '15px'),
        ('font-style', 'italic'),
        ('font-weight', 'bold'),
        ('text-align', 'center')
    ]
}])
# Out:
# <style type="text/css">
# #T_3231e_ caption {
#   color: Black;
#   font-size: 15px;
#   font-style: italic;
#   font-weight: bold;
#   text-align: center;
# }
# </style>
# <table id="T_3231e_">
#   <caption>Demographic Parity Fairness: Searched (Vehicles)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Total # of Stops</th>
#       <th class="col_heading level0 col1" >Percent of Stops</th>
#       <th class="col_heading level0 col2" ># of Searched (Vehicles)</th>
#       <th class="col_heading level0 col3" >Percent of Searched (Vehicles)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Race</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3231e_level0_row0" class="row_heading level0 row0" >white</th>
#       <td id="T_3231e_row0_col0" class="data row0 col0" >162226</td>
#       <td id="T_3231e_row0_col1" class="data row0 col1" >42.49%</td>
#       <td id="T_3231e_row0_col2" class="data row0 col2" >2509</td>
#       <td id="T_3231e_row0_col3" class="data row0 col3" >24.86%</td>
#     </tr>
#     <tr>
#       <th id="T_3231e_level0_row1" class="row_heading level0 row1" >hispanic</th>
#       <td id="T_3231e_row1_col0" class="data row1 col0" >117083</td>
#       <td id="T_3231e_row1_col1" class="data row1 col1" >30.67%</td>
#       <td id="T_3231e_row1_col2" class="data row1 col2" >4326</td>
#       <td id="T_3231e_row1_col3" class="data row1 col3" >42.87%</td>
#     </tr>
#     <tr>
#       <th id="T_3231e_level0_row2" class="row_heading level0 row2" >black</th>
#       <td id="T_3231e_row2_col0" class="data row2 col0" >42705</td>
#       <td id="T_3231e_row2_col1" class="data row2 col1" >11.19%</td>
#       <td id="T_3231e_row2_col2" class="data row2 col2" >2444</td>
#       <td id="T_3231e_row2_col3" class="data row2 col3" >24.22%</td>
#     </tr>
#     <tr>
#       <th id="T_3231e_level0_row3" class="row_heading level0 row3" >asian/pacific islander</th>
#       <td id="T_3231e_row3_col0" class="data row3 col0" >32541</td>
#       <td id="T_3231e_row3_col1" class="data row3 col1" >8.52%</td>
#       <td id="T_3231e_row3_col2" class="data row3 col2" >534</td>
#       <td id="T_3231e_row3_col3" class="data row3 col3" >5.29%</td>
#     </tr>
#     <tr>
#       <th id="T_3231e_level0_row4" class="row_heading level0 row4" >other</th>
#       <td id="T_3231e_row4_col0" class="data row4 col0" >27238</td>
#       <td id="T_3231e_row4_col1" class="data row4 col1" >7.13%</td>
#       <td id="T_3231e_row4_col2" class="data row4 col2" >279</td>
#       <td id="T_3231e_row4_col3" class="data row4 col3" >2.76%</td>
#     </tr>
#   </tbody>
# </table>

# %%
ax = searched_vehicle.plot(y="Total # of Stops", use_index=True , kind="bar", color='lavender')
searched_vehicle.plot(y="# of Searched (Vehicles)", kind="bar", ax=ax, color="plum")
plt.xlabel("Race")
plt.ylabel('Number of people')
plt.title("Distribution of Stops and Searches (Vehicles) per Race", fontdict={'fontsize': 10, 'fontweight':'bold'})
# Out:
# Text(0.5, 1.0, 'Distribution of Stops and Searches (Vehicles) per Race')

# %%
searched_vehicle.plot(y= ['Percent of Stops',"Percent of Searched (Vehicles)"], use_index=True, kind='bar', color =['paleturquoise','teal'])
plt.xlabel("Race")
plt.ylabel('Percentages')
plt.title("Comparison between Percentage of Stops and Searches (Vehicles) per Race", fontdict={'fontsize': 9, 'fontweight':'bold'})
# Out:
# Text(0.5, 1.0, 'Comparison between Percentage of Stops and Searches (Vehicles) per Race')

# %%
arrested_groups = test[test['arrest_made'] == True]['subject_race'].value_counts().to_dict()
arrested_groups
# Out:
# {'white': 1771,
#  'hispanic': 1714,
#  'black': 857,
#  'asian/pacific islander': 309,
#  'other': 160}

# %%
percentage_arrested = aspercent(test[test['arrest_made'] == True]['subject_race'].value_counts(normalize=True),decimals=2).to_dict()
percentage_arrested
# Out:
# {'white': '36.81%',
#  'hispanic': '35.63%',
#  'black': '17.81%',
#  'asian/pacific islander': '6.42%',
#  'other': '3.33%'}

# %%
arrested = pd.DataFrame([demographic_groups, percentage_of_groups, arrested_groups, percentage_arrested],index=['Total # of Stops', 'Percent of Stops', '# of Arrested', 'Percent of Arrested']).T
index = arrested.index
index.name = "Race"
arrested.style.set_caption('Demographic Parity Fairness: Arrested').set_table_styles([{
    'selector': 'caption',
    'props': [
        ('color', 'Black'),
        ('font-size', '15px'),
        ('font-style', 'italic'),
        ('font-weight', 'bold'),
        ('text-align', 'center')
    ]
}])
# Out:
# <style type="text/css">
# #T_15a68_ caption {
#   color: Black;
#   font-size: 15px;
#   font-style: italic;
#   font-weight: bold;
#   text-align: center;
# }
# </style>
# <table id="T_15a68_">
#   <caption>Demographic Parity Fairness: Arrested</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Total # of Stops</th>
#       <th class="col_heading level0 col1" >Percent of Stops</th>
#       <th class="col_heading level0 col2" ># of Arrested</th>
#       <th class="col_heading level0 col3" >Percent of Arrested</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Race</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_15a68_level0_row0" class="row_heading level0 row0" >white</th>
#       <td id="T_15a68_row0_col0" class="data row0 col0" >162226</td>
#       <td id="T_15a68_row0_col1" class="data row0 col1" >42.49%</td>
#       <td id="T_15a68_row0_col2" class="data row0 col2" >1771</td>
#       <td id="T_15a68_row0_col3" class="data row0 col3" >36.81%</td>
#     </tr>
#     <tr>
#       <th id="T_15a68_level0_row1" class="row_heading level0 row1" >hispanic</th>
#       <td id="T_15a68_row1_col0" class="data row1 col0" >117083</td>
#       <td id="T_15a68_row1_col1" class="data row1 col1" >30.67%</td>
#       <td id="T_15a68_row1_col2" class="data row1 col2" >1714</td>
#       <td id="T_15a68_row1_col3" class="data row1 col3" >35.63%</td>
#     </tr>
#     <tr>
#       <th id="T_15a68_level0_row2" class="row_heading level0 row2" >black</th>
#       <td id="T_15a68_row2_col0" class="data row2 col0" >42705</td>
#       <td id="T_15a68_row2_col1" class="data row2 col1" >11.19%</td>
#       <td id="T_15a68_row2_col2" class="data row2 col2" >857</td>
#       <td id="T_15a68_row2_col3" class="data row2 col3" >17.81%</td>
#     </tr>
#     <tr>
#       <th id="T_15a68_level0_row3" class="row_heading level0 row3" >asian/pacific islander</th>
#       <td id="T_15a68_row3_col0" class="data row3 col0" >32541</td>
#       <td id="T_15a68_row3_col1" class="data row3 col1" >8.52%</td>
#       <td id="T_15a68_row3_col2" class="data row3 col2" >309</td>
#       <td id="T_15a68_row3_col3" class="data row3 col3" >6.42%</td>
#     </tr>
#     <tr>
#       <th id="T_15a68_level0_row4" class="row_heading level0 row4" >other</th>
#       <td id="T_15a68_row4_col0" class="data row4 col0" >27238</td>
#       <td id="T_15a68_row4_col1" class="data row4 col1" >7.13%</td>
#       <td id="T_15a68_row4_col2" class="data row4 col2" >160</td>
#       <td id="T_15a68_row4_col3" class="data row4 col3" >3.33%</td>
#     </tr>
#   </tbody>
# </table>

# %%
ax = arrested.plot(y="Total # of Stops", use_index=True , kind="bar", color='lavender')
arrested.plot(y="# of Arrested", kind="bar", ax=ax, color="plum")
plt.xlabel("Race")
plt.ylabel('Number of people')
plt.title("Distribution of Stops and Arrests per Race", fontdict={'fontsize': 10, 'fontweight':'bold'})
# Out:
# Text(0.5, 1.0, 'Distribution of Stops and Arrests per Race')

# %%
arrested.plot(y= ['Percent of Stops',"Percent of Arrested"], use_index=True, kind='bar', color =['paleturquoise','teal'])
plt.xlabel("Race")
plt.ylabel('Percentages')
plt.title("Comparison between Percentage of Stops and Arrests per Race", fontdict={'fontsize': 9, 'fontweight':'bold'})
# Out:
# Text(0.5, 1.0, 'Comparison between Percentage of Stops and Arrests per Race')

# %%
citation_groups = test[test['citation_issued'] == True]['subject_race'].value_counts().to_dict()
citation_groups
# Out:
# {'white': 96631,
#  'hispanic': 67787,
#  'black': 20728,
#  'asian/pacific islander': 17896,
#  'other': 17359}

# %%
percentage_citation = aspercent(test[test['citation_issued'] == True]['subject_race'].value_counts(normalize=True),decimals=2).to_dict()
percentage_citation
# Out:
# {'white': '43.84%',
#  'hispanic': '30.76%',
#  'black': '9.4%',
#  'asian/pacific islander': '8.12%',
#  'other': '7.88%'}

# %%
citation = pd.DataFrame([demographic_groups, percentage_of_groups, citation_groups, percentage_citation],index=['Total # of Stops', 'Percent of Stops', '# of Citations Issued', 'Percent of Citations Issued']).T
index = citation.index
index.name = "Race"
citation.style.set_caption('Demographic Parity Fairness: Citations Issued').set_table_styles([{
    'selector': 'caption',
    'props': [
        ('color', 'Black'),
        ('font-size', '15px'),
        ('font-style', 'italic'),
        ('font-weight', 'bold'),
        ('text-align', 'center')
    ]
}])
# Out:
# <style type="text/css">
# #T_711d7_ caption {
#   color: Black;
#   font-size: 15px;
#   font-style: italic;
#   font-weight: bold;
#   text-align: center;
# }
# </style>
# <table id="T_711d7_">
#   <caption>Demographic Parity Fairness: Citations Issued</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Total # of Stops</th>
#       <th class="col_heading level0 col1" >Percent of Stops</th>
#       <th class="col_heading level0 col2" ># of Citations Issued</th>
#       <th class="col_heading level0 col3" >Percent of Citations Issued</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Race</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_711d7_level0_row0" class="row_heading level0 row0" >white</th>
#       <td id="T_711d7_row0_col0" class="data row0 col0" >162226</td>
#       <td id="T_711d7_row0_col1" class="data row0 col1" >42.49%</td>
#       <td id="T_711d7_row0_col2" class="data row0 col2" >96631</td>
#       <td id="T_711d7_row0_col3" class="data row0 col3" >43.84%</td>
#     </tr>
#     <tr>
#       <th id="T_711d7_level0_row1" class="row_heading level0 row1" >hispanic</th>
#       <td id="T_711d7_row1_col0" class="data row1 col0" >117083</td>
#       <td id="T_711d7_row1_col1" class="data row1 col1" >30.67%</td>
#       <td id="T_711d7_row1_col2" class="data row1 col2" >67787</td>
#       <td id="T_711d7_row1_col3" class="data row1 col3" >30.76%</td>
#     </tr>
#     <tr>
#       <th id="T_711d7_level0_row2" class="row_heading level0 row2" >black</th>
#       <td id="T_711d7_row2_col0" class="data row2 col0" >42705</td>
#       <td id="T_711d7_row2_col1" class="data row2 col1" >11.19%</td>
#       <td id="T_711d7_row2_col2" class="data row2 col2" >20728</td>
#       <td id="T_711d7_row2_col3" class="data row2 col3" >9.4%</td>
#     </tr>
#     <tr>
#       <th id="T_711d7_level0_row3" class="row_heading level0 row3" >asian/pacific islander</th>
#       <td id="T_711d7_row3_col0" class="data row3 col0" >32541</td>
#       <td id="T_711d7_row3_col1" class="data row3 col1" >8.52%</td>
#       <td id="T_711d7_row3_col2" class="data row3 col2" >17896</td>
#       <td id="T_711d7_row3_col3" class="data row3 col3" >8.12%</td>
#     </tr>
#     <tr>
#       <th id="T_711d7_level0_row4" class="row_heading level0 row4" >other</th>
#       <td id="T_711d7_row4_col0" class="data row4 col0" >27238</td>
#       <td id="T_711d7_row4_col1" class="data row4 col1" >7.13%</td>
#       <td id="T_711d7_row4_col2" class="data row4 col2" >17359</td>
#       <td id="T_711d7_row4_col3" class="data row4 col3" >7.88%</td>
#     </tr>
#   </tbody>
# </table>

# %%
ax = citation.plot(y="Total # of Stops", use_index=True , kind="bar", color='lavender')
citation.plot(y="# of Citations Issued", kind="bar", ax=ax, color="plum")
plt.xlabel("Race")
plt.ylabel('Number of people')
plt.title("Distribution of Stops and Citations Issued per Race", fontdict={'fontsize': 10, 'fontweight':'bold'})
# Out:
# Text(0.5, 1.0, 'Distribution of Stops and Citations Issued per Race')

# %%
citation.plot(y= ['Percent of Stops',"Percent of Citations Issued"], use_index=True, kind='bar', color =['paleturquoise','teal'])
plt.xlabel("Race")
plt.ylabel('Percentages')
plt.title("Comparison between Percentage of Stops and Citations Issued per Race", fontdict={'fontsize': 9, 'fontweight':'bold'})
# Out:
# Text(0.5, 1.0, 'Comparison between Percentage of Stops and Citations Issued per Race')

# %%
warning_issued_groups = test[test['warning_issued'] == True]['subject_race'].value_counts().to_dict()
warning_issued_groups
# Out:
# {'white': 50670,
#  'hispanic': 33863,
#  'black': 16780,
#  'asian/pacific islander': 11985,
#  'other': 7139}

# %%
percentage_warning_issued = aspercent(test[test['warning_issued'] == True]['subject_race'].value_counts(normalize=True),decimals=2).to_dict()
percentage_warning_issued
# Out:
# {'white': '42.07%',
#  'hispanic': '28.12%',
#  'black': '13.93%',
#  'asian/pacific islander': '9.95%',
#  'other': '5.93%'}

# %%
warning = pd.DataFrame([demographic_groups, percentage_of_groups, warning_issued_groups, percentage_warning_issued],index=['Total # of Stops', 'Percent of Stops', '# of Warnings Issued', 'Percent of Warnings Issued']).T
index = warning.index
index.name = "Race"
warning.style.set_caption('Demographic Parity Fairness: Warnings Issued').set_table_styles([{
    'selector': 'caption',
    'props': [
        ('color', 'Black'),
        ('font-size', '15px'),
        ('font-style', 'italic'),
        ('font-weight', 'bold'),
        ('text-align', 'center')
    ]
}])
# Out:
# <style type="text/css">
# #T_b0b4f_ caption {
#   color: Black;
#   font-size: 15px;
#   font-style: italic;
#   font-weight: bold;
#   text-align: center;
# }
# </style>
# <table id="T_b0b4f_">
#   <caption>Demographic Parity Fairness: Warnings Issued</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Total # of Stops</th>
#       <th class="col_heading level0 col1" >Percent of Stops</th>
#       <th class="col_heading level0 col2" ># of Warnings Issued</th>
#       <th class="col_heading level0 col3" >Percent of Warnings Issued</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Race</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b0b4f_level0_row0" class="row_heading level0 row0" >white</th>
#       <td id="T_b0b4f_row0_col0" class="data row0 col0" >162226</td>
#       <td id="T_b0b4f_row0_col1" class="data row0 col1" >42.49%</td>
#       <td id="T_b0b4f_row0_col2" class="data row0 col2" >50670</td>
#       <td id="T_b0b4f_row0_col3" class="data row0 col3" >42.07%</td>
#     </tr>
#     <tr>
#       <th id="T_b0b4f_level0_row1" class="row_heading level0 row1" >hispanic</th>
#       <td id="T_b0b4f_row1_col0" class="data row1 col0" >117083</td>
#       <td id="T_b0b4f_row1_col1" class="data row1 col1" >30.67%</td>
#       <td id="T_b0b4f_row1_col2" class="data row1 col2" >33863</td>
#       <td id="T_b0b4f_row1_col3" class="data row1 col3" >28.12%</td>
#     </tr>
#     <tr>
#       <th id="T_b0b4f_level0_row2" class="row_heading level0 row2" >black</th>
#       <td id="T_b0b4f_row2_col0" class="data row2 col0" >42705</td>
#       <td id="T_b0b4f_row2_col1" class="data row2 col1" >11.19%</td>
#       <td id="T_b0b4f_row2_col2" class="data row2 col2" >16780</td>
#       <td id="T_b0b4f_row2_col3" class="data row2 col3" >13.93%</td>
#     </tr>
#     <tr>
#       <th id="T_b0b4f_level0_row3" class="row_heading level0 row3" >asian/pacific islander</th>
#       <td id="T_b0b4f_row3_col0" class="data row3 col0" >32541</td>
#       <td id="T_b0b4f_row3_col1" class="data row3 col1" >8.52%</td>
#       <td id="T_b0b4f_row3_col2" class="data row3 col2" >11985</td>
#       <td id="T_b0b4f_row3_col3" class="data row3 col3" >9.95%</td>
#     </tr>
#     <tr>
#       <th id="T_b0b4f_level0_row4" class="row_heading level0 row4" >other</th>
#       <td id="T_b0b4f_row4_col0" class="data row4 col0" >27238</td>
#       <td id="T_b0b4f_row4_col1" class="data row4 col1" >7.13%</td>
#       <td id="T_b0b4f_row4_col2" class="data row4 col2" >7139</td>
#       <td id="T_b0b4f_row4_col3" class="data row4 col3" >5.93%</td>
#     </tr>
#   </tbody>
# </table>

# %%
ax = warning.plot(y="Total # of Stops", use_index=True , kind="bar", color='lavender')
warning.plot(y="# of Warnings Issued", kind="bar", ax=ax, color="plum")
plt.xlabel("Race")
plt.ylabel('Number of people')
plt.title("Distribution of Stops and Warnings Issued per Race", fontdict={'fontsize': 10, 'fontweight':'bold'})
#warning.plot(y= ['# of Demographic Group',"# of Warnings Issued"], use_index=True, kind='bar')
# Out:
# Text(0.5, 1.0, 'Distribution of Stops and Warnings Issued per Race')

# %%
warning.plot(y= ['Percent of Stops',"Percent of Warnings Issued"], use_index=True, kind='bar', color =['paleturquoise','teal'])
plt.xlabel("Race")
plt.ylabel('Percentages')
plt.title("Comparison between Percentage of Stops and Warnings Issued per Race", fontdict={'fontsize': 9, 'fontweight':'bold'})
# Out:
# Text(0.5, 1.0, 'Comparison between Percentage of Stops and Warnings Issued per Race')
